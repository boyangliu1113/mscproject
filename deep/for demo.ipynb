# %% [markdown]
# # Question Answering using Deep Neural Networks

# %% [markdown]
# # Why Machine Learning?
#
# - The traditional information retrieval way for question answering works very well, especially when you knows what you want exactly.
#
# - But the problem is you need to know what you want exactly, i.e the best key words
#
# - Sometimes this is not easy and bring higher requirement to the user
#
# - For machine learning methods, you can overcome this problem to some extent, by feature engineering (which can take more aspects into consideration than only mathcing the words) or by state of the art deep learning models (which can automaticly learn the relationship from the dataset)
#
# # How?
#
# - Traditional machine learning models were tested with manually extracted features, which mainly considers the similarity between the question and the answer
#
# - Large number of papers related to QA system are looked through. Most of them still using the idea to matching the answer with the question.
#
# - Finally, a deep siamese network model proposed by CS&AI Lab of MIT is applied
#
# # The result
#
#
# - using similarity between concepts insted of specific term search
# - Around 70% accuracy to distinguish right answers from the answer set
# - can take full sentence as the input question and returns the information with a ranked list
# - overcomes the shortcome of elastic search though not as precise as it
# - therfore can be a supplement to be used together

# %%
import tensorflow as tf
import numpy as np
import os
import time
import datetime
from tensorflow.contrib import learn
from input_helpers import InputHelper
import pandas as pd
from preprocess import MyVocabularyProcessor
inpH = InputHelper()
x1_test,x2_test,y_test = inpH.getTestDataSet("validation.txt0", "runs/100_epochs_demo/checkpoints/vocab", 30)
checkpoint_file = "runs/100_epochs_demo/checkpoints/model-3000"
graph = tf.Graph()
# Out:
# Loading testing/labelled data from validation.txt0
# WARNING:tensorflow:From /home/boyang/notebooks/research-information_security/smodel/preprocess.py:33: VocabularyProcessor.__init__ (from tensorflow.contrib.learn.python.learn.preprocessing.text) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# WARNING:tensorflow:From /anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/preprocessing/text.py:154: CategoricalVocabulary.__init__ (from tensorflow.contrib.learn.python.learn.preprocessing.categorical_vocabulary) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# 76

# %% [markdown]
# # Read the original QA file

# %%
test = pd.read_csv("qapair.tsv", delimiter = "\t", header = None)
test = test[test[2]==1]
def dumpTest(x1_text,x2_text,y):
        with open('test.txt','w') as f:
            for text1,text2,label in zip(x1_text,x2_text,y):
                f.write(str(label)+"\t"+str(text1)+"\t"+str(text2)+"\n")        
dumpTest(test[[0]], test[[1]], test[[2]])
def getTestDataSet(self, data_path, vocab_path, max_document_length):
        x1_temp,x2_temp,y = self.getTsvTestData(data_path)
        vocab_processor = MyVocabularyProcessor(max_document_length,min_frequency=0)
        vocab_processor = vocab_processor.restore(vocab_path)
        x1 = np.asarray(list(vocab_processor.transform(x1_temp)))
        x2 = np.asarray(list(vocab_processor.transform(x2_temp)))
        del vocab_processor
        gc.collect()
        return x1,x2, y

# %% [markdown]
# # A new question

# %%
question = "Do you keep a record of all data disposals?"
#question = "Do you have a process to notify RBS of changes to data extraction methodology in advance?"
#question = "Vendor must have and maintain a documented change control process for all changes to the IT production environment where Deutsche Bank information is processed or stored.  Changes to the configuration of IT assets in production environments must be actively managed and documented throughout their lifecycle from initiation to verification and closure."
#question = "Does your company have a defined process to ensure separation of duties between personnel assigned to the development/test environments and those assigned to the production environment?"
#question = "Do you need an ID to enter the building?"

test[3] = question.lower()
vocab_processor = MyVocabularyProcessor(30,min_frequency=0)
vocab_processor = vocab_processor.restore("runs/100_epochs_demo/checkpoints/vocab")
x1 = np.asarray(list(vocab_processor.transform(np.asarray(test[3])))  )
x2 = np.asarray(list(vocab_processor.transform(np.asarray([x.lower() for x in test[1]])))  )
y = test[2]

# %% [markdown]
# # Predict using the model

# %%
with graph.as_default():
    session_conf = tf.ConfigProto(allow_soft_placement=True,log_device_placement=False)
    sess = tf.Session(config=session_conf)
    with sess.as_default():
        saver = tf.train.import_meta_graph("{}.meta".format(checkpoint_file))
        sess.run(tf.initialize_all_variables())
        saver.restore(sess, checkpoint_file)
        input_x1 = graph.get_operation_by_name("input_x1").outputs[0]
        input_x2 = graph.get_operation_by_name("input_x2").outputs[0]
        input_y = graph.get_operation_by_name("input_y").outputs[0]
        dropout_keep_prob = graph.get_operation_by_name("dropout_keep_prob").outputs[0]
        predictions = graph.get_operation_by_name("output/distance").outputs[0]
        accuracy = graph.get_operation_by_name("accuracy/accuracy").outputs[0]
        sim = graph.get_operation_by_name("accuracy/temp_sim").outputs[0]
        batches = inpH.batch_iter(list(zip(x1,x2,y)), 2*64, 1, shuffle=False)
        all_predictions = []
        all_d=[]
        for db in batches:
            x1_dev_b,x2_dev_b,y_dev_b = zip(*db)
            batch_predictions, batch_acc, batch_sim = sess.run([predictions,accuracy,sim], {input_x1: x1_dev_b, input_x2: x2_dev_b, input_y:y_dev_b, dropout_keep_prob: 1.0})
            all_predictions = np.concatenate([all_predictions, batch_predictions])
            all_d = np.concatenate([all_d, batch_sim])
        correct_predictions = float(np.mean(all_d == y_test))
test["score"] = 0.0
for i in range(len(test)):
    test.iat[i,4] = all_predictions[i]
test["d"] = 0
for i in range(len(test)):
    test.iat[i,5] = all_d[i]
test.sort_values("score").to_csv("preres.csv")
# Out:
# WARNING:tensorflow:From /anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# INFO:tensorflow:Restoring parameters from runs/100_epochs_demo/checkpoints/model-3000
# [[array([ 7, 16,  6, 20, 16, 22,  6, 25,  3,  3,  1,  6,  4,  6,  9])
#   array([ 8,  2, 10, 17, 17, 16,  9,  7,  6,  8, 14,  4, 19,  8,  3]) 1.0]
#  [array([ 7, 16,  6, 20, 16, 22,  6, 25,  3,  3,  1,  6,  4,  6,  9])
#   array([ 8,  2, 10, 17, 17, 16,  9,  7,  6,  8, 14,  4, 19,  8,  3]) 1.0]
#  [array([ 7, 16,  6, 20, 16, 22,  6, 25,  3,  3,  1,  6,  4,  6,  9])
#   array([ 8, 10, 13, 10,  6,  7,  4, 13,  4,  6, 10,  5,  6, 16, 19]) 1.0]
#  ...
#  [array([ 7, 16,  6, 20, 16, 22,  6, 25,  3,  3,  1,  6,  4,  6,  9])
#   array([19, 16, 13,  6,  4,  1,  1,  2, 10,  8,  4, 11,  2,  3,  0]) 1.0]
#  [array([ 7, 16,  6, 20, 16, 22,  6, 25,  3,  3,  1,  6,  4,  6,  9])
#   array([19, 16, 13,  6,  4,  1,  1,  2, 10,  8,  4, 11,  2,  3,  0]) 1.0]
#  [array([ 7, 16,  6, 20, 16, 22,  6, 25,  3,  3,  1,  6,  4,  6,  9])
#   array([19, 16, 13,  6,  4,  1,  1,  2, 10,  8,  4, 11,  2,  3,  0]) 1.0]]
# (2116, 3)
# /anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:23: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.

# %%
pd.options.display.max_colwidth= 1000
df_result = test.sort_values("score").head(200)
df_result['score_result'] = 1 - df_result['score']

# %%
question_ls =  list(df_result[0])
answer_ls =  list(df_result[1])
score_ls = list(df_result['score_result'])
print()
print('QUERY:', '"' ,question, '"' )
print()
print('SEARCH RESULT:')
print()
    
for i in range (0,50):
    print('')
    print("\033[1;34m\"{}\"\x1b[0m".format(question_ls[i]))
    print('Answer:', answer_ls[i])
    print('')
    print("\x1b[31m\"{}{}\"\x1b[0m".format('The confidence:',score_ls[i]))
    print('---------------------------------------------------------------------------------------')
# Out:
# QUERY: " Do you keep a record of all data disposals? "
#
# SEARCH RESULT:
#
#
# " Is Internet Usage Policy or equivalent in place which restricts user access to external e-mail accounts, webmail, data sharing (peer to peer, collaborative, sharing tools including cloud services, etc.) chat, and messaging, from your network?  Provide a copy of the Policy."
# Answer: Please see IT Security and Acceptable Use Policy - Internet Use page 6.
#
# "The confidence:0.6068438291549683"
# ---------------------------------------------------------------------------------------
#
# " Do you require all workers (employees, contractors, temps, subcontractors, etc.) with access to Citi information sign a non-disclosure or confidentiality agreement (NDA) as a condition of their employment? "
# Answer: All employees and relevant third parties sign confidentiality or non-disclosure agreements as part of their work tenure.
#
# "The confidence:0.6006975173950195"
# ---------------------------------------------------------------------------------------
#
# "Does your company store media containing clients' information (e.g. printouts, CD's, backup tapes) in a secured environment (i.e. locked room or cabinet with access limited to those who have a business need)?"
# Answer: All tapes are encrypted, and where appropriate tapes are collected weekly and stored by a 3 rd Party at a secure offsite facility.
#
# "The confidence:0.594791978597641"
# ---------------------------------------------------------------------------------------
#
# "Which statement most accurately represents the retention of Personally Identifiable Information (PII) and Business Confidential Information? (Select all that apply)"
# Answer: Data is only retained the minimal amount of time required to perform the expected services
#
# "The confidence:0.5909798443317413"
# ---------------------------------------------------------------------------------------
#
# " Provide the information classification scheme category of Citi data in your systems."
# Answer: Data is labelled according to the matter it is associated with and acquires labelling and handling controls through the matter security model in SharePoint.
#
# "The confidence:0.5903979241847992"
# ---------------------------------------------------------------------------------------
#
# " What are your information classification scheme categories (e.g. Restricted, Confidential, Internal and Public)? "
# Answer: Data is labelled according to the matter it is associated with and acquires labelling and handling controls through the matter security model in SharePoint.
#
# "The confidence:0.5903979241847992"
# ---------------------------------------------------------------------------------------
#
# "Does the information security management policy address Information Classification: Classification of information, and requirements ensuring information is protected based upon it’s classification."
# Answer: Data is labelled according to the matter it is associated with and acquires labelling and handling controls through the matter security model in SharePoint.
#
# "The confidence:0.5903979241847992"
# ---------------------------------------------------------------------------------------
#
# " Do you have a Policy in place which requires the classification of information?  Provide the title of the Policy."
# Answer: Data is labelled according to the matter it is associated with and acquires labelling and handling controls through the matter security model in SharePoint.
#
# "The confidence:0.5903979241847992"
# ---------------------------------------------------------------------------------------
#
# " Are user held accountable for all activity associated with their login IDs? Do you have Acceptable Use Policy or comparable document in place, to ensure accountability for all activities associated with Login IDs?  Provide the title of the Policy. Do employees must acknowledge their acceptance of their accountability for all activities associated with their Login IDs?"
# Answer: All users are held accountable for activity associated with their ID's. This is specified within the Acceptable Use and Confidentiality policies, which are signed on appointment and which apply to all members of a Matter Team.
#
# "The confidence:0.5885981917381287"
# ---------------------------------------------------------------------------------------
#
# " Provide a copy of your Policies, Standards, and Procedures (e.g. Sanitation of Media Devices) related to the destruction and secure disposal of information in the form of paper and/or electronic media."
# Answer: Please see A8 Asset Ref 4  S Secure Disposal policy (Redacted).pdf
#
# "The confidence:0.5872796773910522"
# ---------------------------------------------------------------------------------------
#
# "You utilize email filtering technology inorder to effectively identify and block spyware and malware, including executable attachments and malicious emails and attachments;"
# Answer: Technical: Clifford Chance uses multiple layers of anti-spam, anti-virus, phishing and impersonation protection (whaling protection) solutions before any email is directed to our SMTP gateways. Anti-malware solutions are also installed at the user exchange level to provide protection for mailboxes. Also, Clifford Chance have implemented DKIM funuctionality for email services that originate from the organisation.  Procedure: Awareness is conducted during a month-long Cyber Awareness event held every year, as well as through awareness training which is mandatory during induction.  Periodic phishing simulation campaigns provide Just-in-Time training to users who click on the simulated phishing emails. Additional announcements are also in place to notify users when there is potential outage of a core service or application and any Cyber Event that is deemed critical enough to warrant global or regional broadcast.
#
# "The confidence:0.5871494114398956"
# ---------------------------------------------------------------------------------------
#
# "Your firm has implemented protections against incoming email spoofing using your firm’s domain name;"
# Answer: Technical: Clifford Chance uses multiple layers of anti-spam, anti-virus, phishing and impersonation protection (whaling protection) solutions before any email is directed to our SMTP gateways. Anti-malware solutions are also installed at the user exchange level to provide protection for mailboxes. Also, Clifford Chance have implemented DKIM funuctionality for email services that originate from the organisation.  Procedure: Awareness is conducted during a month-long Cyber Awareness event held every year, as well as through awareness training which is mandatory during induction.  Periodic phishing simulation campaigns provide Just-in-Time training to users who click on the simulated phishing emails. Additional announcements are also in place to notify users when there is potential outage of a core service or application and any Cyber Event that is deemed critical enough to warrant global or regional broadcast.
#
# "The confidence:0.5871494114398956"
# ---------------------------------------------------------------------------------------
#
# "Are allocated user passwords stored at any stage "
# Answer: N The IT Service Access Management (SAM) team processes include specific tasks and checks to be carried out for a role and access rights where appropriate.  Password resets are restricted to the Service Desk, IT SAM, and Domain Admin or Account Operator roles. All these teams and administrative user groups have specifically restricted membership.  Segregation of Duties is achieved through the matter configuration process. The data or system owner is responsible for approving an access request. All access requests are submitted through our ticketing system, and tracked to completion.
#
# "The confidence:0.587090939283371"
# ---------------------------------------------------------------------------------------
#
# "Does your organization perform annual information security reviews over the environment(s) that process and/or stored GE data? Examples of information security reviews include, but are not limited to SSAE 16,  SOC 2  Type 2,  ISAE 4302,  PCI, ISO27001 Certification. Note: The assessment can be performed by an external party or an internal team. If an internal team is leveraged then the team must be independent, qualified and staffed with dedicated members. If the team does not meet all of these aspects please answer "No" and indicate which aspects are not met."
# Answer: The internal/external IT audit or information security assessment for the in scope environment  can be viewed onsite at any Clifford Chance location. Clifford Chance does not provide to external parties confidential information with regards to its Information Security program. However we have been certified to ISO27001 and Cyber Essentials Plus and will provide those certificates as evidence. As part of the ISO27001 certification process we are requried to cover all mandatory controls. We are awaiting the most recent update to our ISO27001 certification extension which includes our US operations in New York and Washington and took place in December 2017
#
# "The confidence:0.5809497535228729"
# ---------------------------------------------------------------------------------------
#
# " Do you restrict user access to external sites that might be used to share information or expose it to malware?"
# Answer: Malicious sites are blocked by deployed access policy. User access from workstations only is authenticated and subject to the corporate browsing policy.
#
# "The confidence:0.5791897773742676"
# ---------------------------------------------------------------------------------------
#
# " Do you maintain the above functions in-house or by a sub-contractor?  Firewall management,  Security configuration management,  Patch management,  Information Security Administration (ISA)."
# Answer: These functions are conducted in-house with aspects out-sourced to trusted third parties
#
# "The confidence:0.5791781544685364"
# ---------------------------------------------------------------------------------------
#
# "Please indicate the type of entitlements permitted using mobile devices."
# Answer: Guest Access Network;Corporate network access
#
# "The confidence:0.5788498520851135"
# ---------------------------------------------------------------------------------------
#
# " Are wireless networks (WLANs) deployed on the network segment where Citi information is stored, processed or transmitted? "
# Answer: Wireless networks (WLANs) are deployed on the network segment where Citi information is stored, processed, transmitted, and approved by Senior Management.
#
# "The confidence:0.5764859020709991"
# ---------------------------------------------------------------------------------------
#
# "Are automatic fire suppression systems inspected and tested by building management, operations or security at all facilities, at least annually?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Are alarm systems in place at all facilities where Citi information is stored, processed and/or transmitted?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Are all smoke and fire detection systems periodically inspected and tested at all facilities where Citi information is stored, processed, or transmitted?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Are smoke or fire detection systems installed at all facilities where Citi information is stored, processed, or transmitted?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Does your procedure include maintaining an inventory of all access cards? If so, please describe."
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Are the facilities security alarm systems tested monthly?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "What type of surveillance monitoring controls are deployed where Citi information is stored, processed and/or transmitted?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "What type of fire suppression systems are installed at facilities where Citi information is stored, processed, or transmitted?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Are recorded images retained for a minimum of 30  days and tested monthly?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "What are the controls used to secure blank access cards?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Are any of your facilities regularly patrolled by security guards?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Is Citi information stored in secure areas with access controls that restrict access only to authorized personnel?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Do you have Emergency Generators located at the facilities  where Citi information is stored, processed and/or transmitted?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Do you have an access control system that logs all access to areas where Citi information is stored, transmitted or processed?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "How are security and fire inspections conducted in all facilities that process, store  or transmit Citi information to monitor the effectiveness and application of the physical security and fire prevention programs?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "Are all visitors required to sign in and provide some form of official identification (e.g. driver’s license, passport, other government ID) to validate their identification?"
# Answer: Please do not answer question for this section, but complete the attached Physical Security Checklist.docx files.
#
# "The confidence:0.5742148458957672"
# ---------------------------------------------------------------------------------------
#
# "15.Your firm utilizes a complex passwords that expire periodically (within 60  – 90  days) and that are unique and not readily reusable;"
# Answer: AD Global Policy and individual group policies define the password strength and compliance policies. For example these include minimum age 1  day, lockout thresholds and do not allow the previous 12  passwords.
#
# "The confidence:0.5736539363861084"
# ---------------------------------------------------------------------------------------
#
# "Does your company install closed circuit television (CCTV) in key areas (internal and external) that hold, process, or transport clients' information and CCTV data is retained for at least 90  days?"
# Answer: CCTV is deployed internally and externally covering the entrances and exits to our buildings and floors. CCTV specific to our Data Centre is provided and managed by the third party who hosts our DC space. CCTV footage is typically retained for a minimum 31  day unless there is a specific section of footage that needs archiving outside these parameters in line with our DPA submission.  Both live and recorded images for our offices are checked daily from our 24 /7/365 Control Room.  A11 Physical Ref 1  S CCTV Cameras
#
# "The confidence:0.5734676122665405"
# ---------------------------------------------------------------------------------------
#
# "Data encryption - details of the algorithms used for various parts of the service provided "
# Answer: Encryption policy in place covering key management.  Clifford Chance uses robust encryption protocols for transferring data both physically and logically. Encryption keys are limited to identified personnel and commensurate with their role. Microsoft BitLocker technology is used for encryption purposes.  Data location Algorithms used (N/A if not applicable) Key Length Supporting Protocols and tools (e.g. SSL, TLS, FTP etc.) Key protection used % of devices encrypted At rest AES 256  2048  Clifford Chance is undertaking a programme of work to migrate storage to one that supports AES 256  by the end of Oct 2018  Native to the Platform 0  In transit AES 256  2048  Data transfer from the client to the the Matter Management System is encrypted Native to the Platform 100  On removable media AES 256  2048  Ivanti (formerly Lumension) Native to the Platform  Emails and attachments TLS 1.2  2048  "TLS (All Clifford Chance e-mail is sent outbound/inbound using TLS encryption All other mail is sent using preferred TLS, which means we always try and deliver using TLS if the receiving e-mail supports it. We offer TLS on all incoming connections, so domains who want to send us with Forced TLS security simply need to add our domain to their forced TLS policy. With TLS, the header information of the transmitted packets is encrypted, but we also support PGP and S/MIME e-mail encryption, where all elements of the e-mail message are encrypted (not just the header information). To enable us to support both e-mail encryption methods we have a cluster of PGP Universal Gateway Servers which can handle both PGP and S/MIME encryption. The PGP Universal Gateway Servers are configurable and allow us to meet the needs of different encryption partners.) " Native to the Platform 100  Laptops XTS AES 128  256  Bitlocker Native to the Platform 100  Backup media AES256 2048   Thales HSM 100  RBS Voice Recorded Data   Voice calls are not recorded  0
#
# "The confidence:0.572938472032547"
# ---------------------------------------------------------------------------------------
#
# "Are internal voice calls encrypted? (I.e. inter-office, including across offices in other sites / regions) Confirm scope, method and exclusions. "
# Answer:  Internal calls are not encrypted.
#
# "The confidence:0.5725252628326416"
# ---------------------------------------------------------------------------------------
#
# " Describe the reporting mechanism.  How frequently does your management review the documented and tracked problems?"
# Answer: The system provides reports and this is reviewed monthly at the Service Management Review meeting.
#
# "The confidence:0.5719253718852997"
# ---------------------------------------------------------------------------------------
#
# " Do you identify all system users by a unique User ID?"
# Answer: All users have a unique ID.
#
# "The confidence:0.571705549955368"
# ---------------------------------------------------------------------------------------
#
# "What are the frequency of risk assessments?"
# Answer: Monthly or less
#
# "The confidence:0.5714626610279083"
# ---------------------------------------------------------------------------------------
#
# "Is there a process to monitor the network devices 24 x7x365 centrally or locally?"
# Answer: Centrally covering all production network components
#
# "The confidence:0.5711595714092255"
# ---------------------------------------------------------------------------------------
#
# "Are controls/processes in place to ensure only authorized software is installed on mobile devices that access, process, store, and/or transmit GE sensitive data?"
# Answer: Answer not provided. Contact Clifford Chance.
#
# "The confidence:0.5711359083652496"
# ---------------------------------------------------------------------------------------
#
# " Are outstanding issues escalated to management?  Does the management reviews and tracks all identified issues to closure?"
# Answer: Issues follow an escalation path and all issues are tracked to closure.
#
# "The confidence:0.5706234872341156"
# ---------------------------------------------------------------------------------------
#
# "Is GE data stored in encrypted form? Examples: If storing data in a database, sensitive data should be encrypted within the database. If storing GE data on laptops, the laptops should have full disk encryption installed. If storing GE data in a network share drive, the drive or the folder where the data resides should be encrypted. If storing GE data on a mobile device, the device should be encrypted."
# Answer: Laptops have full disk encryption as do mobile devices. Existing mitigation: Data on endpoints is encrypted at rest using Microsoft BitLocker. For shared storage in datacenters, data is wide striped across a large number of disks and the disks are mixed data and parity disks which means any one disk only holds fragments of data which the storage array then combines into readable data when requested.  Elements of one file will be cut and striped across a large number of mixed parity disks, e.g. RAID groups contain between 30  and 100  disks. It is not possible to combine the data to obtain meaningful data without having access to A) all disks that hold a particular file and B) the Storage Array which would be required to piece file fragments together.  So in order to obtain usable data one would have to either steal the whole array as is or have sufficient access to work out which disks to steal to form a complete disk aggregate/pool.  For our main CIFS on VNX the data is further protected as the data is wide striped twice on top of each other making it even less likely that anyone stealing one or two disks will be able to get meaningful data out of it.  Obtaining such access would be both extremely difficult and time consuming and given the physical security around our storage arrays is highly unlikely.  Additionally, automated alerts are raised if any disks are removed from the storage arrays, there is CCTV covering datacentre aisles between racks, and for co-location datacenters the storage arrays are in caged areas.  It makes this vector of attack, with the current mechanisms in place, extremely low risk.  Plan: Our global storage refresh & upgrade project has consolidated all storage replacement activity and will implement at-rest encryption by default.  This project is in the final stages of vendor selection and contract agreement.  As the project applies to our core production estate, the plan's timeline for rollout has been set to avoid disruption to clients and will complete by end 2018.   At-rest encryption will be a requirement for all new storage that is procured in the future.
#
# "The confidence:0.5702851712703705"
# ---------------------------------------------------------------------------------------
#
# "Which of the following areas are formally documented in your policy framework? "
# Answer: Unable to answer this question
#
# "The confidence:0.5698096454143524"
# ---------------------------------------------------------------------------------------
#
# "2.     Please describe your external audit environment.  Include and identify all external auditors, regulators, government supervisory agencies and related exams.  Do external auditors regularly perform the following services and if so, how frequently:  (1) financial audit; (2) issuance of internal control reports; and (3) Technology/Computer Controls (e.g. Operations, Security, Change control process, SOC 2,  etc.)?"
# Answer: ISO27001 certified and undergo regular recertification, we are also Cyber Essentials+ accredited. Both certifications are awarded by external bodies. These bodies currently test and assure our IS and wider IT systems, policies and processes.  We are also audited by our clients and provide assurances regarding our security provisions.
#
# "The confidence:0.5697552263736725"
# ---------------------------------------------------------------------------------------
#
# "Please indicate the types of mobile devices allowed in your organization? "
# Answer: Firm-owned & Managed Mobile Device;Personal Mobile (BYOD), but firm hardened and managed device
#
# "The confidence:0.5690969228744507"
# ---------------------------------------------------------------------------------------
#
# " Is your Security Incident Management Standards and Guidelines documented?  Provide a copy of document.  Confirm that the following subjects are covered by the document: roles and responsibilities, reporting of incidents, chain of custody standards, monitoring  24 x7, post mortem, trending, investigative."
# Answer: Please see A16 Incident Ref 1  S Cybersecurity Incident Management Process (Redacted)  Documented incident management process in place to ensure all incidents, which include security incidents, events and issues are appropriately logged, monitored and resolved. This process is overseen by the Service Management Function, which uses a dedicated service portal to log and process all related incidents.  All documentation regarding incident management are reviewed in an ongoing manner with the Service Management Team and tested as required.
#
# "The confidence:0.5680091083049774"
# ---------------------------------------------------------------------------------------
#
# " How do you deliver Information Security Trainings to the staff (e.g. Newsletter, internal e-mails, paper-based handovers, etc.)? "
# Answer: Information Security training is delivered via induction sessions on employees first day, targeted campaigns, internal e-mails and computer based training that is tracked and refreshed. Training is provided for all employees which includes on site third parties and contractors.
#
# "The confidence:0.5678390264511108"
# ---------------------------------------------------------------------------------------

# %%
df_result
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0  \
# 45                                                                                                                                                                                                                                                                                                         Is Internet Usage Policy or equivalent in place which restricts user access to external e-mail accounts, webmail, data sharing (peer to peer, collaborative, sharing tools including cloud services, etc.) chat, and messaging, from your network?  Provide a copy of the Policy.
# 161                                                                                                                                                                                                                                                                                                                                                                           Do you require all workers (employees, contractors, temps, subcontractors, etc.) with access to Citi information sign a non-disclosure or confidentiality agreement (NDA) as a condition of their employment?
# 2041                                                                                                                                                                                                                                                                                                                                                                        Does your company store media containing clients' information (e.g. printouts, CD's, backup tapes) in a secured environment (i.e. locked room or cabinet with access limited to those who have a business need)?
# 423                                                                                                                                                                                                                                                                                                                                                                                                                     Which statement most accurately represents the retention of Personally Identifiable Information (PII) and Business Confidential Information? (Select all that apply)
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Provide the information classification scheme category of Citi data in your systems.
# 89                                                                                                                                                                                                                                                                                                                                                                                                                                                                         What are your information classification scheme categories (e.g. Restricted, Confidential, Internal and Public)?
# 1051                                                                                                                                                                                                                                                                                                                                                                                   Does the information security management policy address Information Classification: Classification of information, and requirements ensuring information is protected based upon it’s classification.
# 88                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Do you have a Policy in place which requires the classification of information?  Provide the title of the Policy.
# 34                                                                                                                                                                                                        Are user held accountable for all activity associated with their login IDs? Do you have Acceptable Use Policy or comparable document in place, to ensure accountability for all activities associated with Login IDs?  Provide the title of the Policy. Do employees must acknowledge their acceptance of their accountability for all activities associated with their Login IDs?
# 103                                                                                                                                                                                                                                                                                                                                                                                Provide a copy of your Policies, Standards, and Procedures (e.g. Sanitation of Media Devices) related to the destruction and secure disposal of information in the form of paper and/or electronic media.
# 1071                                                                                                                                                                                                                                                                                                                                                                                                            You utilize email filtering technology inorder to effectively identify and block spyware and malware, including executable attachments and malicious emails and attachments;
# 1069                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Your firm has implemented protections against incoming email spoofing using your firm’s domain name;
# 1908                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Are allocated user passwords stored at any stage
# 1044  Does your organization perform annual information security reviews over the environment(s) that process and/or stored GE data? Examples of information security reviews include, but are not limited to SSAE 16,  SOC 2  Type 2,  ISAE 4302,  PCI, ISO27001 Certification. Note: The assessment can be performed by an external party or an internal team. If an internal team is leveraged then the team must be independent, qualified and staffed with dedicated members. If the team does not meet all of these aspects please answer "No" and indicate which aspects are not met.
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Do you restrict user access to external sites that might be used to share information or expose it to malware?
# 200                                                                                                                                                                                                                                                                                                                                                                                            Do you maintain the above functions in-house or by a sub-contractor?  Firewall management,  Security configuration management,  Patch management,  Information Security Administration (ISA).
# 583                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Please indicate the type of entitlements permitted using mobile devices.
# 240                                                                                                                                                                                                                                                                                                                                                                                                                                                               Are wireless networks (WLANs) deployed on the network segment where Citi information is stored, processed or transmitted?
# 279                                                                                                                                                                                                                                                                                                                                                                                                                                         Are automatic fire suppression systems inspected and tested by building management, operations or security at all facilities, at least annually?
# 280                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Are alarm systems in place at all facilities where Citi information is stored, processed and/or transmitted?
# 277                                                                                                                                                                                                                                                                                                                                                                                                                                Are all smoke and fire detection systems periodically inspected and tested at all facilities where Citi information is stored, processed, or transmitted?
# 276                                                                                                                                                                                                                                                                                                                                                                                                                                                             Are smoke or fire detection systems installed at all facilities where Citi information is stored, processed, or transmitted?
# 275                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Does your procedure include maintaining an inventory of all access cards? If so, please describe.
# 281                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Are the facilities security alarm systems tested monthly?
# 282                                                                                                                                                                                                                                                                                                                                                                                                                                                               What type of surveillance monitoring controls are deployed where Citi information is stored, processed and/or transmitted?
# 278                                                                                                                                                                                                                                                                                                                                                                                                                                                           What type of fire suppression systems are installed at facilities where Citi information is stored, processed, or transmitted?
# 283                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Are recorded images retained for a minimum of 30  days and tested monthly?
# 274                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 What are the controls used to secure blank access cards?
# 285                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Are any of your facilities regularly patrolled by security guards?
# 272                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Is Citi information stored in secure areas with access controls that restrict access only to authorized personnel?
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 367                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Authentication credentials must be changed whenever a compromise is suspected or has occurred.
# 366                                                                                                                                                                                                              Emergency administrative access must be available and also documented in vendor disaster recovery plans. The emergency access credentials must be held in a secure manner (e.g. under dual control) and available to authorized personnel only. Any use of the emergency credentials must be recorded and the passwords must be changed at the end of the emergency period.
# 365                                                                                                                                                                                                                                                                                                                                                                                                                    PINs, smartcards and biometrics must not be used as a one-factor authentication method for access to IT assets. They must be used in combination with another factor.
# 376                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Installation of unauthorized software must be prohibited.
# 368                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Access to physically secure environments must be denied unless authorized.
# 1596                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Do you have security controls to prevent email borne malware?  Describe the mechanisms on the email gateway.
# 1559                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Do you have security policies / agreements covering end-user IT security obligations?
# 1584                                                                                                                                                                                                                                                                                                Do your password rules meet the following min requirements:   • End-users passwords are at min. 8  char. and complex  • Admin and service a/c passwords are at min. 14 chars complex • User passwords are changed at min. 6 monthly (indicate frequency) Specify your password policy.
# 1563                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Are (at minimum) annual phishing simulations carried out to increase awareness of email risks?
# 1582                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Do you undertake periodical account clean-ups / reviews? Summarise the approach.
# 1581                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Do you have a timely account de-provisioning process?  Summarise the approach.
# 1580                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Do you have processes for granting access based on formal authorisation and restricted permissions?
# 1579                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Do you have a process to notify clients of changes of partners involved in the agreed service
# 1578                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Do you have a process for third party / subcontractor selection, including due diligence checks and risk assessment?
# 1577                                                                                                                                                                                                                                                                                                                                Do you provide clients regular security related reporting?  E.g.   - Access control lists  - Unusual IT events / incidents  - Privilege use etc.  - Security status  - Independent security reviews Confirm what reports are provided and the frequency.
# 1576                                                                                                                                                                                                                                                                                                                                                                                                                                                     Are regular penetration tests carried out by a recognised 3 rd party security company?   Indicate the frequency, scope and partner.
# 1575                                                                                                                                                                                                                                                                                                                                                                                                                                                Do you have independent security accreditations, or independent auditor reviews?  Please indicate which ones, and the date undertaken.
# 1574                                                                                                                                                                                                                                                                                                                                                                                                                               Are “compromise assessments” carried out to check if systems have already been breached?  Indicate how often, and the date and status of the last review.
# 1573                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Are unsupported operating systems / applications and hardware eliminated from the environment? State SLAs for removal.
# 1572                                                                                                                                                                                                                                                                                                                                                                                                                                       Are related internal systems scanned for vulnerabilities to check for known exploits? Indicate the frequency and the target time for remediation.
# 1571                                                                                                                                                                                                                                                                                                                                                                                                                                                 Are related Internet facing perimeter systems scanned for vulnerabilities?  Indicate the frequency and the target time for remediation.
# 1560                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Are client confidentiality clauses included in your end-user contracts and agreements?
# 1570                                                                                                                                                                                                                                                                                                                                                                                                                                                      Are systems (PCs, Servers, Switches, Applications) patched frequently? Indicate the frequency and the target time for remediation.
# 1569                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Do you have a service termination process in place, including conditions, data deletion and hand-over of IP?
# 1568                                                                                                                                                                                                                                                                                                                                                                                                                                                        Do you have a change management process in place for all client services and their underlying systems, including testing phases?
# 1567                                                                                                                                                                                                                                                                                                                                                                                                                   Do you have a security incident process in place, including incident identification, classification, remediation, tracking, communication and continuous improvement?
# 1566                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Do you leverage recognised cyber-security partner(s) to provide ongoing support / advice? Please list key partners.
# 1565                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Do you have dedicated security functions in your organisation? List the active roles.
# 1561                                                                                                                                                                                                                                                                                                                                                                                                               Do your third parties, that are part of services delivered to clients, also comply with your policy framework? Indicate what is included / excluded, or if not relevant
# 1562                                                                                                                                                                                                                                                                                                                                                                                                                                    Are (at minimum) annual security awareness campaigns undertaken to train employees and third parties that are part of services delivered to clients?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1  \
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Please see IT Security and Acceptable Use Policy - Internet Use page 6.
# 161                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     All employees and relevant third parties sign confidentiality or non-disclosure agreements as part of their work tenure.
# 2041                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          All tapes are encrypted, and where appropriate tapes are collected weekly and stored by a 3 rd Party at a secure offsite facility.
# 423                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Data is only retained the minimal amount of time required to perform the expected services
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Data is labelled according to the matter it is associated with and acquires labelling and handling controls through the matter security model in SharePoint.
# 89                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Data is labelled according to the matter it is associated with and acquires labelling and handling controls through the matter security model in SharePoint.
# 1051                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Data is labelled according to the matter it is associated with and acquires labelling and handling controls through the matter security model in SharePoint.
# 88                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Data is labelled according to the matter it is associated with and acquires labelling and handling controls through the matter security model in SharePoint.
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           All users are held accountable for activity associated with their ID's. This is specified within the Acceptable Use and Confidentiality policies, which are signed on appointment and which apply to all members of a Matter Team.
# 103                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Please see A8 Asset Ref 4  S Secure Disposal policy (Redacted).pdf
# 1071  Technical: Clifford Chance uses multiple layers of anti-spam, anti-virus, phishing and impersonation protection (whaling protection) solutions before any email is directed to our SMTP gateways. Anti-malware solutions are also installed at the user exchange level to provide protection for mailboxes. Also, Clifford Chance have implemented DKIM funuctionality for email services that originate from the organisation.  Procedure: Awareness is conducted during a month-long Cyber Awareness event held every year, as well as through awareness training which is mandatory during induction.  Periodic phishing simulation campaigns provide Just-in-Time training to users who click on the simulated phishing emails. Additional announcements are also in place to notify users when there is potential outage of a core service or application and any Cyber Event that is deemed critical enough to warrant global or regional broadcast.
# 1069  Technical: Clifford Chance uses multiple layers of anti-spam, anti-virus, phishing and impersonation protection (whaling protection) solutions before any email is directed to our SMTP gateways. Anti-malware solutions are also installed at the user exchange level to provide protection for mailboxes. Also, Clifford Chance have implemented DKIM funuctionality for email services that originate from the organisation.  Procedure: Awareness is conducted during a month-long Cyber Awareness event held every year, as well as through awareness training which is mandatory during induction.  Periodic phishing simulation campaigns provide Just-in-Time training to users who click on the simulated phishing emails. Additional announcements are also in place to notify users when there is potential outage of a core service or application and any Cyber Event that is deemed critical enough to warrant global or regional broadcast.
# ...
# 1572                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Fully Implemented All internally and externally facing Clifford Chance systems are regularly vulnerability scanned and annual penetration tests carried out where necessary. Clifford Chance uses industry recognised vulnerability management solution to scan and safeguard systems.
# 1571                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Fully Implemented All internally and externally facing Clifford Chance systems are regularly vulnerability scanned and annual penetration tests carried out where necessary. Clifford Chance uses industry recognised vulnerability management solution to scan and safeguard systems.
# 1560                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Fully Implemented Clifford Chance includes relevant security and confidentiality clauses as part of our contracts and agreements with relevant parties.
# 1570                                                                                                                                                                                                                                                                                                                                        Fully Implemented The patching procedure requires that patches are to be released to the Wintel server systems within one month of release date (using preconfigured "Server Patching Groups" set up before the monthly (patch Tuesday) release of security patches by Microsoft). This scheduling is used in order to install security updates to all Wintel servers within the set time frame.   An Emergency (Out of band) patch release process is used only when an IT and Operational Risk assessment has been completed and is triggered by the criticality of the patch and an existing known threat agent.
# 1569                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Fully Implemented Our agreement with Glencore provides that in the event of contract termination, all original books and records would be returned, except that one copy that will be retained for legal and regulatory purposes.  If the contract were to be terminated, Clifford Chance would wish to discuss and a mutually acceptable arrangement, subject to legal regulatory and insurance coverage requirements.
# 1568                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Fully Implemented Clifford Chance maintains a mature Change Control process which oversees all IT change requests.  Changes must be documented in the change management system ahead of time, and are reviewed, impact assessed, and approved by system and service owners, as well as by the independent Change Manager.  Changes must include a risk assessment, implementation place, back-out plan, testing plan, and can only be implemented during the approved time window.
# 1567                                                                                                                                                                                                                                                                                                                                                                                                                                                               Fully Implemented Documented incident management process in place to ensure all incidents, which include security incidents, events and issues are appropriately logged, monitored and resolved.   This process is overseen by the Service Management Function, which uses a dedicated service portal to log and process all related incidents.   All documentation regarding incident management are reviewed in an ongoing manner with the Service Management Team and tested as required.
# 1566                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Fully Implemented  Clifford Chance encourages membership of a variety of industry forums, as well as utilising a specific managed service provider for Cyber Intelligence data.  Clifford Chance is a member of Cyber Security Information Sharing Partnership (CiSP) as well as the Legal Security Forum.
# 1565                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Fully Implemented The Information and Cyber Security Group is comprised of a dedicated Information Security Team and a Cyber Security Team.  These groups are responsible for the review and setting of security policy, advising other groups on correct security best practices, the monitoring of the environment for compliance to the standards, and the remedial actions where the standards are not adhered to.
# 1561                                                                                                                                                                                                                                                                                                                                                                                                                                                Fully Implemented Third Parties are reviewed based on the assessed data risk of the services provided to Clifford Chance at the time of procurement vendor selection.  Service providers complete a Vendor and Security Assessment Questionnaire consisting of Information Security and Data Privacy questions. Findings are recorded, communicated and either the vendor is rejected, or they are accepted, and in the latter case may have some follow-up actions to complete within an agreed timeframe.
# 1562                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Fully Implemented Mandatory training at induction along with annual refreshers, phishing awareness campaigns, cyber security month and targeted training are provided, including but not limited to the communication of security policies and procedures as part of these exercises.
#
#         2                                            3     score  d  \
# 45    1.0  do you keep a record of all data disposals?  0.393156  1
# 161   1.0  do you keep a record of all data disposals?  0.399302  1
# 2041  1.0  do you keep a record of all data disposals?  0.405208  1
# 423   1.0  do you keep a record of all data disposals?  0.409020  1
# 90    1.0  do you keep a record of all data disposals?  0.409602  1
# 89    1.0  do you keep a record of all data disposals?  0.409602  1
# 1051  1.0  do you keep a record of all data disposals?  0.409602  1
# 88    1.0  do you keep a record of all data disposals?  0.409602  1
# 34    1.0  do you keep a record of all data disposals?  0.411402  1
# 103   1.0  do you keep a record of all data disposals?  0.412720  1
# 1071  1.0  do you keep a record of all data disposals?  0.412851  1
# 1069  1.0  do you keep a record of all data disposals?  0.412851  1
# 1908  1.0  do you keep a record of all data disposals?  0.412909  1
# 1044  1.0  do you keep a record of all data disposals?  0.419050  1
# 44    1.0  do you keep a record of all data disposals?  0.420810  1
# 200   1.0  do you keep a record of all data disposals?  0.420822  1
# 583   1.0  do you keep a record of all data disposals?  0.421150  1
# 240   1.0  do you keep a record of all data disposals?  0.423514  1
# 279   1.0  do you keep a record of all data disposals?  0.425785  1
# 280   1.0  do you keep a record of all data disposals?  0.425785  1
# 277   1.0  do you keep a record of all data disposals?  0.425785  1
# 276   1.0  do you keep a record of all data disposals?  0.425785  1
# 275   1.0  do you keep a record of all data disposals?  0.425785  1
# 281   1.0  do you keep a record of all data disposals?  0.425785  1
# 282   1.0  do you keep a record of all data disposals?  0.425785  1
# 278   1.0  do you keep a record of all data disposals?  0.425785  1
# 283   1.0  do you keep a record of all data disposals?  0.425785  1
# 274   1.0  do you keep a record of all data disposals?  0.425785  1
# 285   1.0  do you keep a record of all data disposals?  0.425785  1
# 272   1.0  do you keep a record of all data disposals?  0.425785  1
# ...   ...                                          ...       ... ..
# 367   1.0  do you keep a record of all data disposals?  0.439883  1
# 366   1.0  do you keep a record of all data disposals?  0.439883  1
# 365   1.0  do you keep a record of all data disposals?  0.439883  1
# 376   1.0  do you keep a record of all data disposals?  0.439883  1
# 368   1.0  do you keep a record of all data disposals?  0.439883  1
# 1596  1.0  do you keep a record of all data disposals?  0.439883  1
# 1559  1.0  do you keep a record of all data disposals?  0.439883  1
# 1584  1.0  do you keep a record of all data disposals?  0.439883  1
# 1563  1.0  do you keep a record of all data disposals?  0.439883  1
# 1582  1.0  do you keep a record of all data disposals?  0.439883  1
# 1581  1.0  do you keep a record of all data disposals?  0.439883  1
# 1580  1.0  do you keep a record of all data disposals?  0.439883  1
# 1579  1.0  do you keep a record of all data disposals?  0.439883  1
# 1578  1.0  do you keep a record of all data disposals?  0.439883  1
# 1577  1.0  do you keep a record of all data disposals?  0.439883  1
# 1576  1.0  do you keep a record of all data disposals?  0.439883  1
# 1575  1.0  do you keep a record of all data disposals?  0.439883  1
# 1574  1.0  do you keep a record of all data disposals?  0.439883  1
# 1573  1.0  do you keep a record of all data disposals?  0.439883  1
# 1572  1.0  do you keep a record of all data disposals?  0.439883  1
# 1571  1.0  do you keep a record of all data disposals?  0.439883  1
# 1560  1.0  do you keep a record of all data disposals?  0.439883  1
# 1570  1.0  do you keep a record of all data disposals?  0.439883  1
# 1569  1.0  do you keep a record of all data disposals?  0.439883  1
# 1568  1.0  do you keep a record of all data disposals?  0.439883  1
# 1567  1.0  do you keep a record of all data disposals?  0.439883  1
# 1566  1.0  do you keep a record of all data disposals?  0.439883  1
# 1565  1.0  do you keep a record of all data disposals?  0.439883  1
# 1561  1.0  do you keep a record of all data disposals?  0.439883  1
# 1562  1.0  do you keep a record of all data disposals?  0.439883  1
#
#       score_result
# 45        0.606844
# 161       0.600698
# 2041      0.594792
# 423       0.590980
# 90        0.590398
# 89        0.590398
# 1051      0.590398
# 88        0.590398
# 34        0.588598
# 103       0.587280
# 1071      0.587149
# 1069      0.587149
# 1908      0.587091
# 1044      0.580950
# 44        0.579190
# 200       0.579178
# 583       0.578850
# 240       0.576486
# 279       0.574215
# 280       0.574215
# 277       0.574215
# 276       0.574215
# 275       0.574215
# 281       0.574215
# 282       0.574215
# 278       0.574215
# 283       0.574215
# 274       0.574215
# 285       0.574215
# 272       0.574215
# ...            ...
# 367       0.560117
# 366       0.560117
# 365       0.560117
# 376       0.560117
# 368       0.560117
# 1596      0.560117
# 1559      0.560117
# 1584      0.560117
# 1563      0.560117
# 1582      0.560117
# 1581      0.560117
# 1580      0.560117
# 1579      0.560117
# 1578      0.560117
# 1577      0.560117
# 1576      0.560117
# 1575      0.560117
# 1574      0.560117
# 1573      0.560117
# 1572      0.560117
# 1571      0.560117
# 1560      0.560117
# 1570      0.560117
# 1569      0.560117
# 1568      0.560117
# 1567      0.560117
# 1566      0.560117
# 1565      0.560117
# 1561      0.560117
# 1562      0.560117
#
# [200 rows x 7 columns]
