# %% [markdown]
# # Question Answering using Deep Neural Networks

# %% [markdown]
# # Why Machine Learning?
#
# - The traditional information retrieval way for question answering works very well, especially when you knows what you want exactly.
#
# - But the problem is you need to know what you want exactly, i.e the best key words
#
# - Sometimes this is not easy and bring higher requirement to the user
#
# - For machine learning methods, you can overcome this problem to some extent, by feature engineering (which can take more aspects into consideration than only mathcing the words) or by state of the art deep learning models (which can automaticly learn the relationship from the dataset)
#
# # How?
#
# - Traditional machine learning models were tested with manually extracted features, which mainly considers the similarity between the question and the answer
#
# - Large number of papers related to QA system are looked through. Most of them still using the idea to matching the answer with the question.
#
# - Finally, a deep siamese network model proposed by CS&AI Lab of MIT is applied
#
# # The result
#
#
# - using similarity between concepts insted of specific term search
# - Around 70% accuracy to distinguish right answers from the answer set
# - can take full sentence as the input question and returns the information with a ranked list
# - overcomes the shortcome of elastic search though not as precise as it
# - therfore can be a supplement to be used together

# %%
import tensorflow as tf
import numpy as np
import os
import time
import datetime
from tensorflow.contrib import learn
from input_helpers import InputHelper
import pandas as pd
from preprocess import MyVocabularyProcessor
inpH = InputHelper()
x1_test,x2_test,y_test = inpH.getTestDataSet("validation.txt0", "runs/100_epochs_merged_demo/checkpoints/vocab", 30)
checkpoint_file = "runs/100_epochs_merged_demo/checkpoints/model-4000"
graph = tf.Graph()
# Out:
# Loading testing/labelled data from validation.txt0
# WARNING:tensorflow:From /home/boyang/notebooks/research-information_security/smodel/preprocess.py:33: VocabularyProcessor.__init__ (from tensorflow.contrib.learn.python.learn.preprocessing.text) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# WARNING:tensorflow:From /anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/preprocessing/text.py:154: CategoricalVocabulary.__init__ (from tensorflow.contrib.learn.python.learn.preprocessing.categorical_vocabulary) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# 76

# %% [markdown]
# # Read the original QA file

# %%
test = pd.read_csv("qa_merged.tsv", delimiter = "\t", header = None)
test = test[test[2]==1]
def dumpTest(x1_text,x2_text,y):
        with open('test.txt','w') as f:
            for text1,text2,label in zip(x1_text,x2_text,y):
                f.write(str(label)+"\t"+str(text1)+"\t"+str(text2)+"\n")        
dumpTest(test[[0]], test[[1]], test[[2]])
def getTestDataSet(self, data_path, vocab_path, max_document_length):
        x1_temp,x2_temp,y = self.getTsvTestData(data_path)
        vocab_processor = MyVocabularyProcessor(max_document_length,min_frequency=0)
        vocab_processor = vocab_processor.restore(vocab_path)
        x1 = np.asarray(list(vocab_processor.transform(x1_temp)))
        x2 = np.asarray(list(vocab_processor.transform(x2_temp)))
        del vocab_processor
        gc.collect()
        return x1,x2, y

# %% [markdown]
# # A new question

# %%
#question = "Do you keep a record of all data disposals?"
question = "Do you have a process to notify RBS of changes to data extraction methodology in advance?"
#question = "Vendor must have and maintain a documented change control process for all changes to the IT production environment where Deutsche Bank information is processed or stored.  Changes to the configuration of IT assets in production environments must be actively managed and documented throughout their lifecycle from initiation to verification and closure."
#question = "Does your company have a defined process to ensure separation of duties between personnel assigned to the development/test environments and those assigned to the production environment?"
#question = "Do you need an ID to enter the building?"

test[3] = question.lower()
vocab_processor = MyVocabularyProcessor(30,min_frequency=0)
vocab_processor = vocab_processor.restore("runs/100_epochs_merged_demo/checkpoints/vocab")
x1 = np.asarray(list(vocab_processor.transform(np.asarray(test[3])))  )
x2 = np.asarray(list(vocab_processor.transform(np.asarray([x.lower() for x in test[1]])))  )
y = test[2]

# %% [markdown]
# # Predict using the model

# %%
with graph.as_default():
    session_conf = tf.ConfigProto(allow_soft_placement=True,log_device_placement=False)
    sess = tf.Session(config=session_conf)
    with sess.as_default():
        saver = tf.train.import_meta_graph("{}.meta".format(checkpoint_file))
        sess.run(tf.initialize_all_variables())
        saver.restore(sess, checkpoint_file)
        input_x1 = graph.get_operation_by_name("input_x1").outputs[0]
        input_x2 = graph.get_operation_by_name("input_x2").outputs[0]
        input_y = graph.get_operation_by_name("input_y").outputs[0]
        dropout_keep_prob = graph.get_operation_by_name("dropout_keep_prob").outputs[0]
        predictions = graph.get_operation_by_name("output/distance").outputs[0]
        accuracy = graph.get_operation_by_name("accuracy/accuracy").outputs[0]
        sim = graph.get_operation_by_name("accuracy/temp_sim").outputs[0]
        batches = inpH.batch_iter(list(zip(x1,x2,y)), 2*64, 1, shuffle=False)
        all_predictions = []
        all_d=[]
        for db in batches:
            x1_dev_b,x2_dev_b,y_dev_b = zip(*db)
            batch_predictions, batch_acc, batch_sim = sess.run([predictions,accuracy,sim], {input_x1: x1_dev_b, input_x2: x2_dev_b, input_y:y_dev_b, dropout_keep_prob: 1.0})
            all_predictions = np.concatenate([all_predictions, batch_predictions])
            all_d = np.concatenate([all_d, batch_sim])
        correct_predictions = float(np.mean(all_d == y_test))
test["score"] = 0.0
for i in range(len(test)):
    test.iat[i,4] = all_predictions[i]
test["d"] = 0
for i in range(len(test)):
    test.iat[i,5] = all_d[i]
test.sort_values("score").to_csv("preres.csv")
# Out:
# WARNING:tensorflow:From /anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# INFO:tensorflow:Restoring parameters from runs/100_epochs_merged_demo/checkpoints/model-4000
# [[array([ 7, 16,  1, 20, 16, 22,  1, 14,  5, 26,  4,  1,  5,  1,  2])
#   array([ 1,  2,  3,  4,  5,  6,  4,  1,  7,  4,  6,  8,  9, 10, 11]) 1.0]
#  [array([ 7, 16,  1, 20, 16, 22,  1, 14,  5, 26,  4,  1,  5,  1,  2])
#   array([ 1,  2,  3,  4,  5,  6,  4,  1,  2,  9, 16, 26, 10,  7,  4]) 1.0]
#  [array([ 7, 16,  1, 20, 16, 22,  1, 14,  5, 26,  4,  1,  5,  1,  2])
#   array([ 1,  5,  9,  4,  1, 13, 14, 10,  6,  1, 16, 17, 17, 10,  8]) 1.0]
#  ...
#  [array([ 7, 16,  1, 20, 16, 22,  1, 14,  5, 26,  4,  1,  5,  1,  2])
#   array([17, 16,  9,  1, 22,  6,  4,  9,  1,  5, 22, 13, 14,  4, 19]) 1.0]
#  [array([ 7, 16,  1, 20, 16, 22,  1, 14,  5, 26,  4,  1,  5,  1,  2])
#   array([ 7, 16,  4,  6,  1, 20, 16, 22,  9,  1,  8, 16, 23,  2,  5]) 1.0]
#  [array([ 7, 16,  1, 20, 16, 22,  1, 14,  5, 26,  4,  1,  5,  1,  2])
#   array([ 7, 16,  4,  6,  1, 14,  6, 11,  8,  1,  6, 16,  3,  4,  3]) 1.0]]
# (2116, 3)
# /anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:23: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.

# %%
pd.options.display.max_colwidth= 1000
df_result = test.sort_values("score").head(200)
df_result['score_result'] = 1 - df_result['score']

# %%
question_ls =  list(df_result[0])
answer_ls =  list(df_result[1])
score_ls = list(df_result['score_result'])
print()
print('QUERY:', '"' ,question, '"' )
print()
print('SEARCH RESULT:')
print()
    
for i in range (0,50):
    print('')
    print("\033[1;34m\"{}\"\x1b[0m".format(question_ls[i]))
    print('Answer:', answer_ls[i])
    print('')
    print("\x1b[31m\"{}{}\"\x1b[0m".format('The confidence:',score_ls[i]))
    print('---------------------------------------------------------------------------------------')
# Out:
# QUERY: " Do you have a process to notify RBS of changes to data extraction methodology in advance? "
#
# SEARCH RESULT:
#
#
# "Do you have a process for granting and documenting access, including access for subcontractors and remote access? List the person(s)/group(s) responsible for granting access. Please describe the process, including any tools utilized."
# Answer: Do you have a process for granting and documenting access, including access for subcontractors and remote access? List the person(s)/group(s) responsible for granting access. Please describe the process, including any tools utilized. Yes Access rights are granted based on standard access templates in line with business roles, and are augmented by specific additional rights on an as needed basis with data owner approval. The IT Service Access Management (SAM) team processes include specific tasks and checks to be carried out for a role and access rights where appropriate, these include Joiners, Movers and Leavers as well as remote access. The SAM team use a variety of tools including but not limited to Active Driectory and Remote Access Token Services.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a policy in place to enforce encryption on external storage devices?"
# Answer: Do you have a policy in place to enforce encryption on external storage devices? Fully Implemented Encryption policy in place covering key management. Clifford Chance uses robust encryption protocols for storing and transferring data both physically and logically. Encryption keys are limited to identified personnel and commensurate with their role.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to restrict production data from being used in development and testing environments? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment."
# Answer: Do you have a process to restrict production data from being used in development and testing environments? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to perform peer / independent code reviews for each release? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment."
# Answer: Do you have a process to perform peer / independent code reviews for each release? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Not Applicable We do peer assessment on change control.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to perform vulnerability scans and penetration testing for all software releases? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment."
# Answer: Do you have a process to perform vulnerability scans and penetration testing for all software releases? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for the maintenance of segregation of duties between the development, testing and production environments? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment."
# Answer: Do you have a process for the maintenance of segregation of duties between the development, testing and production environments? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to log and monitor access to the program source code on a periodic basis? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment."
# Answer: Do you have a process to log and monitor access to the program source code on a periodic basis? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to remove information prior to decommissioning equipment that housed, stored, processed, controlled or accessed client information? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment."
# Answer: Do you have a process to remove information prior to decommissioning equipment that housed, stored, processed, controlled or accessed client information? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place to track and record errors/losses, on a timely basis, as they are discovered? Do you analyze these events to understand their root causes and then address and escalate to management? Provide evidence of regulatory and/or operational errors resulting in financial loss, if applicable."
# Answer: Do you have a process in place to track and record errors/losses, on a timely basis, as they are discovered? Do you analyze these events to understand their root causes and then address and escalate to management? Provide evidence of regulatory and/or operational errors resulting in financial loss, if applicable. N/A N/A
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to remediate/take appropriate actions and follow up and report on significant deficiencies that were identified through self-, internal-, external- audits and SOX reviews? Provide your most recent internal and external audit remediation items. "
# Answer: Do you have a process to remediate/take appropriate actions and follow up and report on significant deficiencies that were identified through self-, internal-, external- audits and SOX reviews? Provide your most recent internal and external audit remediation items.  N/A N/A
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to approve exceptions to the established security policies? Please describe the process."
# Answer: Do you have a process to approve exceptions to the established security policies? Please describe the process. Yes Clifford Chance as part of our ISO27001 Certification operate a ISMS with appropriate oversight as required by the certification standards body. We are in the process of formally documented a waiver and exception process with business risk which is due to launch in 2018.  Currently exceptions are recorded in an ad Hoc manner
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to remove JPMC information prior to decommissioning equipment that housed, stored, processed, controlled or accessed JPMC information? Describe your procedures for the decommissioning process. Describe if the same procedure is utilized for non-repairable equipment. "
# Answer: Do you have a process to remove JPMC information prior to decommissioning equipment that housed, stored, processed, controlled or accessed JPMC information? Describe your procedures for the decommissioning process. Describe if the same procedure is utilized for non-repairable equipment.  Yes All assets are recorded into the Asset Management system, at the time of issuance and collection. Reports against the assets are maintaing and managed by the relevant Asset Managers as required. Asset and Information Disposal is covered by the Clifford chance Secure Disposal Policy. Any destruction of externally hosted data is covered by the relevant third party contract.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a physical and environmental security program to protect JPMC resources (information, documentation etc.)? Provide physical and environmental security program details. "
# Answer: Do you have a physical and environmental security program to protect JPMC resources (information, documentation etc.)? Provide physical and environmental security program details.  Yes Clifford Chance maintain relevant physical and environmental controls in line with our commitment to the ISO 27001  Information Security Management System.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place to confirm the identity of the individuals before allowing them to update their individual information? (Select all that apply)"
# Answer: Do you have a process in place to confirm the identity of the individuals before allowing them to update their individual information? (Select all that apply) Yes, Individuals have access to the data sets to make changes themselves
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place that allows individuals to request that their personal data is updated or amended? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment."
# Answer: Do you have a process in place that allows individuals to request that their personal data is updated or amended? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Yes. Procedures are in place to facilitate consent and subject access requests.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process certify, authorize and re-certify firewall rules on a periodic basis? Please describe how firewall rule certification, authorization and periodic review is performed"
# Answer: Do you have a process certify, authorize and re-certify firewall rules on a periodic basis? Please describe how firewall rule certification, authorization and periodic review is performed Yes Firewalls are used on all egress points from the Clifford Chance Global Network.  They are configured "Default Deny" and only very specific services are permitted through the firewall from dedicated hosts and to relevant external systems. The Network Configuration standard outlines the design for the overall network.  Firewall rules are subject to regular reviews and all changes to policies go through CAB including Emergency Changes if necessary.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to review changes post-implementation for emergency fixes? Please describe process."
# Answer: Do you have a process to review changes post-implementation for emergency fixes? Please describe process. Yes The Change Management process includes facility for emergency changes, where business services are impacted, or are at imminent risk of impact requiring exceptional sign-off from a member of senior IT management. This process also includes reviewing the root cause of the emergency event precipitating the emergency change.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to notify RBS of changes to data extraction methodology in advance?"
# Answer: Do you have a process to notify RBS of changes to data extraction methodology in advance? Clifford Chance maintains a mature Change Control process which oversees all IT change requests. Changes must be documented in the change management system ahead of time, and are reviewed, impact assessed, and approved by system and service owners, as well as by the independent Change Manager.  Changes must include a risk assessment, implementation place, back-out plan, testing plan, and can only be implemented during the approved time window.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for storing security tapes, and content of other physical security monitoring devices / video devices? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment."
# Answer: Do you have a process for storing security tapes, and content of other physical security monitoring devices / video devices? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Yes, All details kept on a fully redundant security system server
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to notify clients of changes of partners involved in the agreed service"
# Answer: Do you have a process to notify clients of changes of partners involved in the agreed service Fully Implemented Clients will be notified as agreed based on contractual requirements.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to document and obtain sign-off on business requirements, including those for information security, before commencing detailed design? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment."
# Answer: Do you have a process to document and obtain sign-off on business requirements, including those for information security, before commencing detailed design? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Not Applicable Clifford chance does not develop software applications.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for third party / subcontractor selection, including due diligence checks and risk assessment?"
# Answer: Do you have a process for third party / subcontractor selection, including due diligence checks and risk assessment? Fully Implemented Third Parties are reviewed based on the assessed data risk of the services provided to Clifford Chance at the time of procurement vendor selection. Vendors are required to complete a questionnaire and answer specific questions and queries either via email, or in a scheduled meeting.   Findings are recorded, communicated and either the vendor is rejected, or they are accepted, and in the latter case may have some follow-up actions to complete within an agreed timeframe.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place for the management of generic accounts on systems and applications (e.g. root on UNIX, SYS on Oracle)?  NB: A generic user account is a non-unique account that is not assigned to a single individual and, in many cases, is shared amongst a number of users i.e. Administrator, Guest. "
# Answer: Do you have a process in place for the management of generic accounts on systems and applications (e.g. root on UNIX, SYS on Oracle)?  NB: A generic user account is a non-unique account that is not assigned to a single individual and, in many cases, is shared amongst a number of users i.e. Administrator, Guest.  N/A Generic accounts are not used to provide services to RBS.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place for security patch management?"
# Answer: Do you have a process in place for security patch management? Yes,  The patching procedure requires that patches are to be released to the Wintel server systems within 1  month of release date (using preconfigured "Server Patching Groups" set up before the monthly (patch Tuesday) release of security patches by Microsoft). This scheduling is used in order to install security updates to all Wintel servers within the set time frame.  The deployement of patches executued by an software tool which allows for installs and deinstallations.     An Emergency (Out of band) patch release process is used only when an IT and Operational Risk assessment has been completed and is triggered by the criticality of the patch and an existing known threat agent.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place to govern the retrieval of records? Does it include… Instructions on secure handling Timelines for collections A record of approvals? A log of all retrieval activity? "
# Answer: Do you have a process in place to govern the retrieval of records? Does it include… Instructions on secure handling Timelines for collections A record of approvals? A log of all retrieval activity?  Instructions on secure handling.  Yes Timelines for collections.  Yes A record of approvals?  Yes A log of all retrieval activity?   Yes  Clifford Chance uses an offsite approved vendor who use secure handling and tracking methods; in our handling of records onsite at our offices also we also use secure methods for registration and storage.   Records collections onsite are dealt with upon request and within daily deadlines; Collections from our offices by our offsite vendor occur once each day.    Records retrieval requests are accepted from  registered users and/or those authorised to access restricted documents (as applicable)     Full activity histories are logged against all matters cases and folders, which include a timed and logged record of retrievals
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for managing alerts generated by Transactional activity (including transaction number)?"
# Answer: Do you have a process for managing alerts generated by Transactional activity (including transaction number)? Yes, Clifford Chance have DLP in place in a variety of services, which are continually monitored and improved on an on-going basis. Suspicious activity of users and attempts at un-authorised activity are reviewed daily, monitored and escalated where appropriate. Significant events identified, researched and escalated to the Cyber Security team.  Dedicated suite of services exist with advanced Malware detection, malware content inspection, URL filtering, site filtering according to corporate policy, and advanced inspection services.  Documented incident management process in place to ensure all incidents, which include security incidents, events and issues are appropriately logged, monitored and resolved.   This process is overseen by the Service Management Function, which uses a dedicated service portal to log and process all related incidents.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to implement and update signatures on network devices based on new-found threats? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Please provide the frequency of signature updates."
# Answer: Do you have a process to implement and update signatures on network devices based on new-found threats? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Please provide the frequency of signature updates. Yes. Internal Process Daily
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for managing alerts generated by privileged user activity including adding, modifying and deleting accounts?"
# Answer: Do you have a process for managing alerts generated by privileged user activity including adding, modifying and deleting accounts? Yes, Clifford Chance have DLP in place in a variety of services, which are continually monitored and improved on an on-going basis. Suspicious activity of users and attempts at un-authorised activity are reviewed daily, monitored and escalated where appropriate. Significant events identified, researched and escalated to the Cyber Security team.  Dedicated suite of services exist with advanced Malware detection, malware content inspection, URL filtering, site filtering according to corporate policy, and advanced inspection services.  Documented incident management process in place to ensure all incidents, which include security incidents, events and issues are appropriately logged, monitored and resolved.   This process is overseen by the Service Management Function, which uses a dedicated service portal to log and process all related incidents.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place to detect and prevent unauthorized devices from physically connecting to the internal network? If yes, please upload supporting documentation and/or provide an overview.  If no, please provide comment."
# Answer: Do you have a process in place to detect and prevent unauthorized devices from physically connecting to the internal network? If yes, please upload supporting documentation and/or provide an overview.  If no, please provide comment. Yes. There are varying solutions designed to protect against unauthorised access such as network access, USB and other removable media.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for password resets and changes?"
# Answer: Do you have a process for password resets and changes? Y The IT Service Access Management (SAM) team processes include specific tasks and checks to be carried out for a role and access rights where appropriate.  Password resets are restricted to the Service Desk, IT SAM, and Domain Admin or Account Operator roles. All these teams and administrative user groups have specifically restricted membership.  Segregation of Duties is achieved through the matter configuration process. The data or system owner is responsible for approving an access request. All access requests are submitted through our ticketing system, and tracked to completion.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for ensuring Third Parties acting on behalf of your company sign a non-disclosure or confidentiality agreement prior to accessing your information (including RBS information residing within your environment)?"
# Answer: Do you have a process for ensuring Third Parties acting on behalf of your company sign a non-disclosure or confidentiality agreement prior to accessing your information (including RBS information residing within your environment)? Yes,   CC provide all services to RBS using a variety of different technologies, but these are managed and run by CC staff. We do not provide confidential information or technical documentation on these services to 3 rd parties. We can however provide redacted versions of documents either remotely or on site.  Clifford Chance runs an Enterprise Risk Management process to identify risks across all major risk categories at an operational and strategic level. This is owned by the General Counsel, is reviewed annually by the General Counsel and Executive Leadership Group and was last reviewed in December 2017.  This is also reviewed annually by the Audit Committee, with the last review also in December 2017.    Clifford Chance has an ongoing Information Security improvement strategy and investment programme that continually reviews existing control frameworks, current and emerging threats, technological changes both in security and broader IT, and business driven risk mitigation.  Third Parties are reviewed based on the assessed data risk of the services provided to Clifford Chance at the time of procurement vendor selection. Vendors are required to complete a questionnaire and answer specific questions and queries either via email, or in a scheduled meeting.   Findings are recorded, communicated and either the vendor is rejected, or they are accepted, and in the latter case may have some follow-up actions to complete within an agreed timeframe.  Security incident reporting will be as per contractual agreement.   We use our standard terms and conditions which include EU model clauses for our sub contractors.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for managing alerts for devices being connected to the IT network?"
# Answer: Do you have a process for managing alerts for devices being connected to the IT network? Yes, Clifford Chance have DLP in place in a variety of services, which are continually monitored and improved on an on-going basis. Suspicious activity of users and attempts at un-authorised activity are reviewed daily, monitored and escalated where appropriate. Significant events identified, researched and escalated to the Cyber Security team.  Dedicated suite of services exist with advanced Malware detection, malware content inspection, URL filtering, site filtering according to corporate policy, and advanced inspection services.  Documented incident management process in place to ensure all incidents, which include security incidents, events and issues are appropriately logged, monitored and resolved.   This process is overseen by the Service Management Function, which uses a dedicated service portal to log and process all related incidents.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for managing alerts from IT network gateways and firewalls?"
# Answer: Do you have a process for managing alerts from IT network gateways and firewalls? Yes, Clifford Chance have DLP in place in a variety of services, which are continually monitored and improved on an on-going basis. Suspicious activity of users and attempts at un-authorised activity are reviewed daily, monitored and escalated where appropriate. Significant events identified, researched and escalated to the Cyber Security team.  Dedicated suite of services exist with advanced Malware detection, malware content inspection, URL filtering, site filtering according to corporate policy, and advanced inspection services.  Documented incident management process in place to ensure all incidents, which include security incidents, events and issues are appropriately logged, monitored and resolved.   This process is overseen by the Service Management Function, which uses a dedicated service portal to log and process all related incidents.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for managing alerts generated by IT system events, including alerts for:  -Data loss prevention system alert -Deployment of malware protection -malware detection -system start-up and shutdown -changes to IT system configuration, content files and critical system files -Changes to, or attempts to change, security settings and controls -User login and logoff times -Wireless intrusion monitoring -Successful and unsuccessful access attempts to IT systems storing or processing RBS information classified as Secret or Confidential  For the alerts mentioned above, is there an escalation process once they have been issued?"
# Answer: Do you have a process for managing alerts generated by IT system events, including alerts for:  -Data loss prevention system alert -Deployment of malware protection -malware detection -system start-up and shutdown -changes to IT system configuration, content files and critical system files -Changes to, or attempts to change, security settings and controls -User login and logoff times -Wireless intrusion monitoring -Successful and unsuccessful access attempts to IT systems storing or processing RBS information classified as Secret or Confidential  For the alerts mentioned above, is there an escalation process once they have been issued?    Yes -Data loss prevention system alert -Deployment of malware protection -malware detection -system start-up and shutdown -changes to IT system configuration, content files and critical system files -changes to, or attempts to change, security settings and controls -User login and logoff times -Wireless intrusion monitoring -Successful and unsuccessful access attempts to IT systems storing or processing RBS information classified as Secret or Confidential  Yes there is an escalation process once they have been issued  Clifford Chance have DLP in place in a variety of services, which are continually monitored and improved on an on-going basis. Suspicious activity of users and attempts at un-authorised activity are reviewed daily, monitored and escalated where appropriate. Significant events identified, researched and escalated to the Cyber Security team.  Dedicated suite of services exist with advanced Malware detection, malware content inspection, URL filtering, site filtering according to corporate policy, and advanced inspection services.  Documented incident management process in place to ensure all incidents, which include security incidents, events and issues are appropriately logged, monitored and resolved.   This process is overseen by the Service Management Function, which uses a dedicated service portal to log and process all related incidents.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to disable / wipe company data if the mobile device is stolen or lost? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment."
# Answer: Do you have a process to disable / wipe company data if the mobile device is stolen or lost? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment. Yes. Done via Mobile Device Management (MDM)
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to ensure user identification is verified (authenticated) "
# Answer: Do you have a process to ensure user identification is verified (authenticated)  Y The IT Service Access Management (SAM) team processes include specific tasks and checks to be carried out for a role and access rights where appropriate.  Password resets are restricted to the Service Desk, IT SAM, and Domain Admin or Account Operator roles. All these teams and administrative user groups have specifically restricted membership.  Segregation of Duties is achieved through the matter configuration process. The data or system owner is responsible for approving an access request. All access requests are submitted through our ticketing system, and tracked to completion.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to perform security monitoring within the cloud environment? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment."
# Answer: Do you have a process to perform security monitoring within the cloud environment? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for collating and undertaking trend analysis"
# Answer: Do you have a process for collating and undertaking trend analysis Yes,  Clifford Chance have DLP in place in a variety of services, which are continually monitored and improved on an on-going basis. Suspicious activity of users and attempts at un-authorised activity are reviewed daily, monitored and escalated where appropriate. Significant events identified, researched and escalated to the Cyber Security team.  Dedicated suite of services exist with advanced Malware detection, malware content inspection, URL filtering, site filtering according to corporate policy, and advanced inspection services.  Documented incident management process in place to ensure all incidents, which include security incidents, events and issues are appropriately logged, monitored and resolved.   This process is overseen by the Service Management Function, which uses a dedicated service portal to log and process all related incidents.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to perform intrusion detection to detect and prevent intrusion into the global cloud infrastructure? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment."
# Answer: Do you have a process to perform intrusion detection to detect and prevent intrusion into the global cloud infrastructure? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a procedure for reporting results to nominated staff members"
# Answer: Do you have a procedure for reporting results to nominated staff members Yes,  Clifford Chance have DLP in place in a variety of services, which are continually monitored and improved on an on-going basis. Suspicious activity of users and attempts at un-authorised activity are reviewed daily, monitored and escalated where appropriate. Significant events identified, researched and escalated to the Cyber Security team.  Dedicated suite of services exist with advanced Malware detection, malware content inspection, URL filtering, site filtering according to corporate policy, and advanced inspection services.  Documented incident management process in place to ensure all incidents, which include security incidents, events and issues are appropriately logged, monitored and resolved.   This process is overseen by the Service Management Function, which uses a dedicated service portal to log and process all related incidents.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place for patching underlying services and systems and hardening operating systems to enterprise and industry standards? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment."
# Answer: Do you have a process in place for patching underlying services and systems and hardening operating systems to enterprise and industry standards? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place for hardening operating systems to enterprise and industry standards? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment."
# Answer: Do you have a process in place for hardening operating systems to enterprise and industry standards? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place that facilitates the prevention of man in the middle attacks? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment."
# Answer: Do you have a process in place that facilitates the prevention of man in the middle attacks? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to enumerate global firewall, IDS, and IPS rules protecting clients' VPC (Virtual Private Cloud) environments and virtual instances? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment."
# Answer: Do you have a process to enumerate global firewall, IDS, and IPS rules protecting clients' VPC (Virtual Private Cloud) environments and virtual instances? If yes, please upload supporting documentation and/or provide overview.  If no, please provide comment. Not Applicable
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place to provide staff training on legislative and regulatory requirements for each applicable regulation and related jurisdiction? If yes, please upload supporting documentation and/or provide overview. If no, please provide details of how you communicate this information to staff."
# Answer: Do you have a process in place to provide staff training on legislative and regulatory requirements for each applicable regulation and related jurisdiction? If yes, please upload supporting documentation and/or provide overview. If no, please provide details of how you communicate this information to staff. Yes. Regular training on key points of regulatory compliance provided at induction and as required on a risk based approach.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to manage and monitor current and future capacity requirements to ensure optimum IT system performance?"
# Answer: Do you have a process to manage and monitor current and future capacity requirements to ensure optimum IT system performance? Yes, This is carried out by our Infrastructure and Systems operations function.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process in place to independently ensure compliance with any legal, regulatory or industry requirements, including analysis of the regulation / legislative / industry requirements in all geographic and jurisdictional locations your clients and employees operate in? If yes, please upload supporting documentation and/or provide overview, including which department / function manages this process. If no, please provide comment."
# Answer: Do you have a process in place to independently ensure compliance with any legal, regulatory or industry requirements, including analysis of the regulation / legislative / industry requirements in all geographic and jurisdictional locations your clients and employees operate in? If yes, please upload supporting documentation and/or provide overview, including which department / function manages this process. If no, please provide comment. No. We have local compliance teams in the regional hubs and an internal audit function.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process for standard security configurations for networks, operating systems, images (to include virtualized images and snapshots) applications, and desktops? Describe whether the process includes security patches, vulnerability management, default passwords, registry settings, version management, file directory rights and permissions."
# Answer: Do you have a process for standard security configurations for networks, operating systems, images (to include virtualized images and snapshots) applications, and desktops? Describe whether the process includes security patches, vulnerability management, default passwords, registry settings, version management, file directory rights and permissions. Yes.Core system are configured to standard templates which include security and service hardening. Clifford Chance have introduced Desired State Configuration (DSC) process which checks the compliance against our systems. The System Engineering team utilise a Server Hardening standard which details the specific hardening steps and industry best practice adopted within the configuration and build procedure.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a process to perform periodic reviews of subcontractor user access rights to ensure appropriateness of access (to your and any JPMC systems)? Describe and provide evidence of the most recent access review."
# Answer: Do you have a process to perform periodic reviews of subcontractor user access rights to ensure appropriateness of access (to your and any JPMC systems)? Describe and provide evidence of the most recent access review. Yes.Clifford Chance perform regular reviews on secure areas in line with our commitment to ISO 27001  Information Security Management System.
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------
#
# "Do you have a Policy and/or process to notify Businesses when Infrastructure and Software technology is due to become End of Life and/or End of Support? If yes, please describe the process.  Are the exceptions (if any) communicated to external business partners? "
# Answer: Do you have a Policy and/or process to notify Businesses when Infrastructure and Software technology is due to become End of Life and/or End of Support? If yes, please describe the process.  Are the exceptions (if any) communicated to external business partners?  No,  Response not provided
#
# "The confidence:0.829696387052536"
# ---------------------------------------------------------------------------------------

# %%
df_result
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0  \
# 730                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Do you have a process for granting and documenting access, including access for subcontractors and remote access? List the person(s)/group(s) responsible for granting access. Please describe the process, including any tools utilized.
# 1611                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Do you have a policy in place to enforce encryption on external storage devices?
# 638                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Do you have a process to restrict production data from being used in development and testing environments? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment.
# 639                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Do you have a process to perform peer / independent code reviews for each release? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment.
# 641                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Do you have a process to perform vulnerability scans and penetration testing for all software releases? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment.
# 647                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Do you have a process for the maintenance of segregation of duties between the development, testing and production environments? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment.
# 648                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Do you have a process to log and monitor access to the program source code on a periodic basis? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment.
# 659                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Do you have a process to remove information prior to decommissioning equipment that housed, stored, processed, controlled or accessed client information? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment.
# 671                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Do you have a process in place to track and record errors/losses, on a timely basis, as they are discovered? Do you analyze these events to understand their root causes and then address and escalate to management? Provide evidence of regulatory and/or operational errors resulting in financial loss, if applicable.
# 672                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Do you have a process to remediate/take appropriate actions and follow up and report on significant deficiencies that were identified through self-, internal-, external- audits and SOX reviews? Provide your most recent internal and external audit remediation items.
# 675                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Do you have a process to approve exceptions to the established security policies? Please describe the process.
# 685                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Do you have a process to remove JPMC information prior to decommissioning equipment that housed, stored, processed, controlled or accessed JPMC information? Describe your procedures for the decommissioning process. Describe if the same procedure is utilized for non-repairable equipment.
# 687                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Do you have a physical and environmental security program to protect JPMC resources (information, documentation etc.)? Provide physical and environmental security program details.
# 437                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Do you have a process in place to confirm the identity of the individuals before allowing them to update their individual information? (Select all that apply)
# 436                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Do you have a process in place that allows individuals to request that their personal data is updated or amended? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment.
# 712                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Do you have a process certify, authorize and re-certify firewall rules on a periodic basis? Please describe how firewall rule certification, authorization and periodic review is performed
# 726                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Do you have a process to review changes post-implementation for emergency fixes? Please describe process.
# 1702                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Do you have a process to notify RBS of changes to data extraction methodology in advance?
# 1479                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Do you have a process for storing security tapes, and content of other physical security monitoring devices / video devices? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment.
# 1579                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Do you have a process to notify clients of changes of partners involved in the agreed service
# 623                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Do you have a process to document and obtain sign-off on business requirements, including those for information security, before commencing detailed design? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment.
# 1578                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Do you have a process for third party / subcontractor selection, including due diligence checks and risk assessment?
# 1914                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Do you have a process in place for the management of generic accounts on systems and applications (e.g. root on UNIX, SYS on Oracle)?  NB: A generic user account is a non-unique account that is not assigned to a single individual and, in many cases, is shared amongst a number of users i.e. Administrator, Guest.
# 1728                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Do you have a process in place for security patch management?
# 1694                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Do you have a process in place to govern the retrieval of records? Does it include… Instructions on secure handling Timelines for collections A record of approvals? A log of all retrieval activity?
# 1716                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Do you have a process for managing alerts generated by Transactional activity (including transaction number)?
# 552                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Do you have a process to implement and update signatures on network devices based on new-found threats? If yes, please upload supporting documentation and/or provide overview. If no, please provide comment. Please provide the frequency of signature updates.
# 1717                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Do you have a process for managing alerts generated by privileged user activity including adding, modifying and deleting accounts?
# 554                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Do you have a process in place to detect and prevent unauthorized devices from physically connecting to the internal network? If yes, please upload supporting documentation and/or provide an overview.  If no, please provide comment.
# 1903                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Do you have a process for password resets and changes?
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 1518                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       If you have sustained a major outage in the last 12  months, please advise if the following have occurred. (Select all that apply)
# 443                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Have you had any recent data breaches by you or by a third party that processes personal data on your behalf that required notification to any regulator or authority?
# 1763                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Do you allow the use of removable media or other IT storage devices? How many people have access to transfer data on to removable media? (Number) Do you have technical controls in place to stop RBS data being transferred to removable media or other IT storage devices?  Do you have a process to allow/approve use of removable media Is there an audit trail in place to monitor access and log data transfers? Frequency of review of these logs
# 714                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Do you allow third parties to connect remotely to your environment? Describe control/containment methods. (Answer "N/A, if no third party access is allowed.)
# 990                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Do you have transactional authority levels, inclusive of limits established based on role, responsibility or position? Describe the governance, and re-approval and monitoring process for maintaining these authority levels. Do you have an exceptions approval process and are these recorded in accordance with corp policy? Describe the exception process.
# 56                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Do you have control process in place to detect or prevent unauthorized security administration changes?  What is your documented process to detect and/or prevent unauthorized entitlement modifications?
# 50     Do you have controls in place to disable the ability to write data to all types of removable storage media devices (including but not limited to USB drives, ZIP drives, CDs, DVDs, etc.)?  If such external devices are not allowed to use: I.)  Please provide  copy of the related documentations of controls. II.)  Do you have domain group policy to disable external drives and prevent the usage? III.)  Does the technical control operate effectively even when the computer is booted in Safe Mode? IV.)  Are Anti-virus software installed to detect and prevent the use of all type of removable storage devices?  If such external devices are allowed to use: I.)  Is the documented process to approve and allow the usage of such external devices in place? II.)  Is a documented rationale required for such use? III.)  Are all devices identified, inventoried and only approved instances can be used? IV.)  Is the inventory of machines allowing data to be copied to removable media maintained? V.)  Is d...
# 728                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Do you plan and monitor SLA(s), KPI(s), system and network capacity, performance and transaction levels? Describe the capacity and demand planning.
# 1107                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            How and when was the information security policy published to employees, constituents, relevant stakeholders?
# 662                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  How do you manage decommissioning upon termination of the service with the subcontractors, consultants or other vendors?
# 897                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Do you have a mechanism to capture and record consent of data privacy preferences, if necessary by law?
# 418                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  How are compliance issues escalated? (e.g.  whistle blowing is one escalation mechanism)
# 1628                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Are physical security controls applied at the IT facility, where client data is stored?   Provide details of the locations and methods used.
# 1677                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Do you hold any RBS data within End User Developed Applications (EUDAs)?
# 529                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Is all data encrypted during transmission? If yes, please upload supporting documentation (e.g. network diagram, encryption standards) and/or provide overview. If no, please provide comment.
# ...
# 749                                                                                                                                                                                                                                                                                                                                                              Do you have controls and tools to safeguard data transmissions including JPMC's Financial Messages? Please provide the details. Financial Messages may be any form of instructions or execution of those instructions (e.g., execution orders, confirmations, acknowledgements, payments). N/A Clifford Chance do not provide financial services to JPMC. We provide Legal Professional Services via vareity of ways which include  email, transfer of data to/from Clifford Chance is over a TLS secured upload site, or via TLS encrypted email, or other encrypted data transfer methods. Enforced TLS can be configured on our email gateways on a per client basis.
# 663                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Do you have controls in place to ensure that office equipment, such as faxes and printers, are clear of sensitive information throughout the day and after business hours, and that access to printed output is restricted? Yes FollowMe printing is secure as access is granted only by the users unique work ID card.
# 825                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Do you have controls to safeguard the information during transport? Describe the controls of the secure transportation environment.  Yes.Clifford Chance make sure that our suppliers follow security best practices. Such as vehicle tracking, secure storage locks for documents and other appropriate physical controls.
# 1749                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Do you have controls in place for Printing and the use of Multi-Functional Devices(MFD)?  Y Business Services uses the secure "FollowMe" printing system. The solution requires the user to register their building access card, or login with their domain login before documents can be printed. Unprinted documents are deleted from the queue after 24  hours.
# 1742                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Do you have controls in place to ensure unauthorised actions on the network will be suitably escalated and appropriate action taken? Yes  Clifford Chance maintains a network Intrusion Detection system as well as host logging and monitoring.  Significant events identified, researched and escalated to the Cyber Security team.
# 906                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Do you have controls to safeguard and retrieve any physical documentation received from JPMC during storage? Please describe the controls. Yes.On the Professional Standards Intranet Site, there is specific guidance associated with handling of information assets which is captured within the "Information Barriers" section.  This addresses the permissible physical location and storage of any document that is related to a sensitive matter.
#
#         2  \
# 730   1.0
# 1611  1.0
# 638   1.0
# 639   1.0
# 641   1.0
# 647   1.0
# 648   1.0
# 659   1.0
# 671   1.0
# 672   1.0
# 675   1.0
# 685   1.0
# 687   1.0
# 437   1.0
# 436   1.0
# 712   1.0
# 726   1.0
# 1702  1.0
# 1479  1.0
# 1579  1.0
# 623   1.0
# 1578  1.0
# 1914  1.0
# 1728  1.0
# 1694  1.0
# 1716  1.0
# 552   1.0
# 1717  1.0
# 554   1.0
# 1903  1.0
# ...   ...
# 1518  1.0
# 443   1.0
# 1763  1.0
# 714   1.0
# 990   1.0
# 56    1.0
# 50    1.0
# 728   1.0
# 1107  1.0
# 662   1.0
# 897   1.0
# 418   1.0
# 1628  1.0
# 1677  1.0
# 529   1.0
# 1832  1.0
# 504   1.0
# 1186  1.0
# 1435  1.0
# 1792  1.0
# 1015  1.0
# 853   1.0
# 804   1.0
# 997   1.0
# 749   1.0
# 663   1.0
# 825   1.0
# 1749  1.0
# 1742  1.0
# 906   1.0
#
#                                                                                               3  \
# 730   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1611  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 638   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 639   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 641   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 647   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 648   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 659   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 671   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 672   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 675   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 685   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 687   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 437   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 436   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 712   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 726   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1702  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1479  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1579  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 623   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1578  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1914  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1728  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1694  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1716  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 552   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1717  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 554   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1903  do you have a process to notify rbs of changes to data extraction methodology in advance?
# ...                                                                                         ...
# 1518  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 443   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1763  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 714   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 990   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 56    do you have a process to notify rbs of changes to data extraction methodology in advance?
# 50    do you have a process to notify rbs of changes to data extraction methodology in advance?
# 728   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1107  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 662   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 897   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 418   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1628  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1677  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 529   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1832  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 504   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1186  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1435  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1792  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1015  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 853   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 804   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 997   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 749   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 663   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 825   do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1749  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 1742  do you have a process to notify rbs of changes to data extraction methodology in advance?
# 906   do you have a process to notify rbs of changes to data extraction methodology in advance?
#
#          score  d  score_result
# 730   0.170304  1      0.829696
# 1611  0.170304  1      0.829696
# 638   0.170304  1      0.829696
# 639   0.170304  1      0.829696
# 641   0.170304  1      0.829696
# 647   0.170304  1      0.829696
# 648   0.170304  1      0.829696
# 659   0.170304  1      0.829696
# 671   0.170304  1      0.829696
# 672   0.170304  1      0.829696
# 675   0.170304  1      0.829696
# 685   0.170304  1      0.829696
# 687   0.170304  1      0.829696
# 437   0.170304  1      0.829696
# 436   0.170304  1      0.829696
# 712   0.170304  1      0.829696
# 726   0.170304  1      0.829696
# 1702  0.170304  1      0.829696
# 1479  0.170304  1      0.829696
# 1579  0.170304  1      0.829696
# 623   0.170304  1      0.829696
# 1578  0.170304  1      0.829696
# 1914  0.170304  1      0.829696
# 1728  0.170304  1      0.829696
# 1694  0.170304  1      0.829696
# 1716  0.170304  1      0.829696
# 552   0.170304  1      0.829696
# 1717  0.170304  1      0.829696
# 554   0.170304  1      0.829696
# 1903  0.170304  1      0.829696
# ...        ... ..           ...
# 1518  0.651475  0      0.348525
# 443   0.652652  0      0.347348
# 1763  0.656796  0      0.343204
# 714   0.656796  0      0.343204
# 990   0.657483  0      0.342517
# 56    0.658013  0      0.341987
# 50    0.658013  0      0.341987
# 728   0.658384  0      0.341616
# 1107  0.658526  0      0.341474
# 662   0.658785  0      0.341215
# 897   0.661182  0      0.338818
# 418   0.662238  0      0.337762
# 1628  0.662790  0      0.337210
# 1677  0.664221  0      0.335779
# 529   0.664221  0      0.335779
# 1832  0.664835  0      0.335165
# 504   0.665061  0      0.334939
# 1186  0.665352  0      0.334648
# 1435  0.666324  0      0.333676
# 1792  0.667122  0      0.332878
# 1015  0.667122  0      0.332878
# 853   0.667122  0      0.332878
# 804   0.667122  0      0.332878
# 997   0.667122  0      0.332878
# 749   0.667122  0      0.332878
# 663   0.667122  0      0.332878
# 825   0.667122  0      0.332878
# 1749  0.667122  0      0.332878
# 1742  0.667122  0      0.332878
# 906   0.667122  0      0.332878
#
# [200 rows x 7 columns]
